# %% [markdown]
# <a href="https://colab.research.google.com/github/Alekhya1707/Colab/blob/master/Code_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing libraries
import pandas as pd
import numpy as np

# %%
# importing data sets
holidays_events = pd.read_csv("holidays_events.csv")
items = pd.read_csv("items.csv")
oil = pd.read_csv("oil.csv")
stores = pd.read_csv("stores.csv")
transactions = pd.read_csv("transactions.csv")

# %%
print(holidays_events)

# %%
print(items)
# Out:
#       item_nbr            family  class  perishable
# 0        96995         GROCERY I   1093           0
# 1        99197         GROCERY I   1067           0
# 2       103501          CLEANING   3008           0
# 3       103520         GROCERY I   1028           0
# 4       103665      BREAD/BAKERY   2712           1
# ...        ...               ...    ...         ...
# 4095   2132318         GROCERY I   1002           0
# 4096   2132945         GROCERY I   1026           0
# 4097   2132957         GROCERY I   1068           0
# 4098   2134058         BEVERAGES   1124           0
# 4099   2134244  LIQUOR,WINE,BEER   1364           0
#
# [4100 rows x 4 columns]

# %%
print(oil)
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
print(stores)
# Out:
#     store_nbr           city                           state type  cluster
# 0           1          Quito                       Pichincha    D       13
# 1           2          Quito                       Pichincha    D       13
# 2           3          Quito                       Pichincha    D        8
# 3           4          Quito                       Pichincha    D        9
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 5           6          Quito                       Pichincha    D       13
# 6           7          Quito                       Pichincha    D        8
# 7           8          Quito                       Pichincha    D        8
# 8           9          Quito                       Pichincha    B        6
# 9          10          Quito                       Pichincha    C       15
# 10         11        Cayambe                       Pichincha    B        6
# ...

# %%
print(transactions)
# Out:
#              date  store_nbr  transactions
# 0      2013-01-01         25           770
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# ...           ...        ...           ...
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802
#
# [83488 rows x 3 columns]

# %%
H_E = holidays_events

# %%
# Finding Missing Values
H_E.isnull().sum()
# Out:
# date           0
# type           0
# locale         0
# locale_name    0
# description    0
# transferred    0
# dtype: int64

# %%
items.isnull().sum()
# Out:
# item_nbr      0
# family        0
# class         0
# perishable    0
# dtype: int64

# %%
oil.isnull().sum()
# Out:
# date           0
# dcoilwtico    43
# dtype: int64

# %%
stores.isnull().sum()
# Out:
# store_nbr    0
# city         0
# state        0
# type         0
# cluster      0
# dtype: int64

# %%
transactions.isnull().sum()
# Out:
# date            0
# store_nbr       0
# transactions    0
# dtype: int64

# %%
# Summary
H_E.describe()
# Out:
#               date     type    locale locale_name description transferred
# count          350      350       350         350         350         350
# unique         312        6         3          24         103           2
# top     2014-06-25  Holiday  National     Ecuador    Carnaval       False
# freq             4      221       174         174          10         338

# %%
items.describe()
# Out:
#            item_nbr      class   perishable
# count  4.100000e+03  4100.0000  4100.000000
# mean   1.251436e+06  2169.6500     0.240488
# std    5.876872e+05  1484.9109     0.427432
# min    9.699500e+04  1002.0000     0.000000
# 25%    8.181108e+05  1068.0000     0.000000
# 50%    1.306198e+06  2004.0000     0.000000
# 75%    1.904918e+06  2990.5000     0.000000
# max    2.134244e+06  7780.0000     1.000000

# %%
np.round(items.describe(), 2)
# Out:
#          item_nbr    class  perishable
# count     4100.00  4100.00     4100.00
# mean   1251436.31  2169.65        0.24
# std     587687.22  1484.91        0.43
# min      96995.00  1002.00        0.00
# 25%     818110.75  1068.00        0.00
# 50%    1306197.50  2004.00        0.00
# 75%    1904918.00  2990.50        0.00
# max    2134244.00  7780.00        1.00

# %%
oil.describe()
# Out:
#         dcoilwtico
# count  1175.000000
# mean     67.714366
# std      25.630476
# min      26.190000
# 25%      46.405000
# 50%      53.190000
# 75%      95.660000
# max     110.620000

# %%
stores.describe()
# Out:
#        store_nbr    cluster
# count  54.000000  54.000000
# mean   27.500000   8.481481
# std    15.732133   4.693395
# min     1.000000   1.000000
# 25%    14.250000   4.000000
# 50%    27.500000   8.500000
# 75%    40.750000  13.000000
# max    54.000000  17.000000

# %%
transactions.describe()
# Out:
#           store_nbr  transactions
# count  83488.000000  83488.000000
# mean      26.939237   1694.602158
# std       15.608204    963.286644
# min        1.000000      5.000000
# 25%       13.000000   1046.000000
# 50%       27.000000   1393.000000
# 75%       40.000000   2079.000000
# max       54.000000   8359.000000

# %%
# Data types
H_E.dtypes
# Out:
# date           object
# type           object
# locale         object
# locale_name    object
# description    object
# transferred      bool
# dtype: object

# %%
items.dtypes
# Out:
# item_nbr       int64
# family        object
# class          int64
# perishable     int64
# dtype: object

# %%
oil.dtypes
# Out:
# date           object
# dcoilwtico    float64
# dtype: object

# %%
stores.dtypes
# Out:
# store_nbr     int64
# city         object
# state        object
# type         object
# cluster       int64
# dtype: object

# %%
transactions.dtypes
# Out:
# date            object
# store_nbr        int64
# transactions     int64
# dtype: object

# %%
oil.dropna()
# Out:
#             date  dcoilwtico
# 0     2013-01-01        0.00
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.isnull().head()
# Out:
#     date  dcoilwtico
# 0  False        True
# 1  False       False
# 2  False       False
# 3  False       False
# 4  False       False

# %%
oil.isnull().sum()
# Out:
# date          0
# dcoilwtico    0
# dtype: int64

# %%
oil = oil.fillna(0)

# %%
oil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01        0.00
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
oil.isnull().sum()
# Out:
# date          0
# dcoilwtico    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Plots for Holidays events
ax = H_E['type'].value_counts().plot(kind='bar',
                                    figsize=(10,5),
                                    title="Type count")
ax.set_xlabel("type")
ax.set_ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
ax = H_E['locale'].value_counts().plot(kind='bar',
                                    figsize=(10,6),
                                    title="Locale count")
ax.set_xlabel("locale")
ax.set_ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
ax = H_E['locale_name'].value_counts().plot(kind='bar',
                                    figsize=(10,7),
                                    title="Locale_name count")
ax.set_xlabel("locale_name")
ax.set_ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
ax = H_E['description'].value_counts().plot(kind='bar',
                                    figsize=(14,8),
                                    title="Description count")
ax.set_xlabel("description")
ax.set_ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
ax = H_E['transferred'].value_counts().plot(kind='bar',
                                    figsize=(14,8),
                                    title="Transferred count")
ax.set_xlabel("transferred")
ax.set_ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
# Plots for items
ax = items['class'].value_counts().plot(kind='bar',
                                    figsize=(14,8),
                                    title="Class count")
ax.set_xlabel("class")
ax.set_ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
ax = items['family'].value_counts().plot(kind='bar',
                                    figsize=(10,6),
                                    title="Count of family")
ax.set_xlabel("family")
ax.set_ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
ax = items['perishable'].value_counts().plot(kind='bar',
                                    figsize=(14,8),
                                    title="Perishable count")
ax.set_xlabel("perishable")
ax.set_ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
dcoilwtico 
ax = oil['dcoilwtico'].value_counts().plot(kind='bar',
                                    figsize=(10,6),
                                    title="Perishable count")
ax.set_xlabel("dcoilwtico")
ax.set_ylabel("count")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-194cddaa6b53> in <module>()
# ----> 1 dcoilwtico
#       2 ax = oil['dcoilwtico'].value_counts().plot(kind='bar',
#       3                                     figsize=(10,6),
#       4                                     title="Perishable count")
#       5 ax.set_xlabel("dcoilwtico")
#
# NameError: name 'dcoilwtico' is not defined

# %%
oil.plot()

# %%
# Plots for stores
ax = stores['city'].value_counts().plot(kind='bar',
                                    figsize=(10,6),
                                    title="City count")
ax.set_xlabel("city")
ax.set_ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
ax = stores['state'].value_counts().plot(kind='bar',
                                    figsize=(10,6),
                                    title="State count")
ax.set_xlabel("state")
ax.set_ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
ax = stores['type'].value_counts().plot(kind='bar',
                                    figsize=(10,6),
                                    title="Type count")
ax.set_xlabel("type")
ax.set_ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
ax = stores['cluster'].value_counts().plot(kind='bar',
                                    figsize=(10,6),
                                    title="Cluster count")
ax.set_xlabel("cluster")
ax.set_ylabel("count")
# Out:
# Text(0, 0.5, 'count')
